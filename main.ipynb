# %%
import requests
import base64
import pandas as pd
import time
from typing import List, Optional

# --- CONFIGURATION ---
CLIENT_ID = '5f857178968840c6ac260b716ccccb4e'
CLIENT_SECRET = '95e7fed22a1849b7b2d9c1880877a2f6'
PLAYLIST_ID = '0oD5aLzUQiIomu805F3xDH'

# --- AUTHENTICATION ---
def get_spotify_token() -> str:
    """Get Spotify access token using Client Credentials flow."""
    auth_url = 'https://accounts.spotify.com/api/token'
    auth_header = base64.b64encode(f"{CLIENT_ID}:{CLIENT_SECRET}".encode()).decode()
    auth_data = {'grant_type': 'client_credentials'}
    auth_headers = {
        'Authorization': f'Basic {auth_header}',
        'Content-Type': 'application/x-www-form-urlencoded'
    }

    response = requests.post(auth_url, data=auth_data, headers=auth_headers)
    response.raise_for_status()
    return response.json()['access_token']

# --- TEST PLAYLIST ACCESS ---
def test_playlist_access(access_token: str, playlist_id: str) -> bool:
    """Test if we can access the playlist and get basic info."""
    url = f'https://api.spotify.com/v1/playlists/{playlist_id}'
    headers = {'Authorization': f'Bearer {access_token}'}
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        playlist_data = response.json()
        print("Successfully accessed playlist!")
        print(f"Playlist Name: {playlist_data['name']}")
        print(f"Description: {playlist_data.get('description', 'No description')}")
        print(f"Number of Tracks: {playlist_data['tracks']['total']}")
        return True
    except requests.exceptions.HTTPError as e:
        print(f"Failed to access playlist: {e}")
        if response.status_code == 404:
            print("This usually means:")
            print("1. The playlist ID is incorrect")
            print("2. The playlist is private or doesn't exist")
            print("3. There's a regional restriction")
        print(f"Status Code: {response.status_code}")
        return False

# --- GET PLAYLIST TRACKS ---
def get_playlist_tracks(access_token: str, playlist_id: str) -> List[dict]:
    """
    Fetches tracks from a given playlist with proper error handling.
    Handles pagination and null tracks.
    """
    url = f'https://api.spotify.com/v1/playlists/{playlist_id}/tracks'
    headers = {'Authorization': f'Bearer {access_token}'}
    params = {'limit': 50, 'offset': 0}
    all_tracks = []
    
    try:
        while True:
            response = requests.get(url, headers=headers, params=params)
            response.raise_for_status()
            data = response.json()
            
            for item in data['items']:
                track_info = item['track']
                if track_info is None:
                    continue
                
                if track_info.get('is_local', False) or not track_info.get('id'):
                    continue
                    
                track_data = {
                    'track_name': track_info['name'],
                    'track_id': track_info['id'],
                    'artist_name': ', '.join([artist['name'] for artist in track_info['artists']]),
                    'artist_id': track_info['artists'][0]['id'] if track_info['artists'] else None,
                    'album_name': track_info['album']['name'],
                    'popularity': track_info['popularity'],
                    'duration_ms': track_info['duration_ms'],
                    'explicit': track_info['explicit']
                }
                all_tracks.append(track_data)
            
            if data['next']:
                params['offset'] += params['limit']
                time.sleep(0.1)
            else:
                break
                
    except requests.exceptions.HTTPError as e:
        print(f"Error fetching playlist tracks: {e}")
        if 'response' in locals():
            print(f"Status Code: {response.status_code}")
        return []
    
    return all_tracks

# --- GET AUDIO FEATURES ---
def get_audio_features(access_token: str, track_ids: List[str]) -> List[dict]:
    """
    Fetches audio features for tracks with proper error handling.
    Handles chunking, rate limiting, and invalid track IDs.
    """
    url = 'https://api.spotify.com/v1/audio-features'
    headers = {'Authorization': f'Bearer {access_token}'}
    all_audio_features = []
    
    valid_track_ids = [tid for tid in track_ids if tid and isinstance(tid, str)]
    print(f"Fetching audio features for {len(valid_track_ids)} valid track IDs...")
    
    for i in range(0, len(valid_track_ids), 100):
        chunk = valid_track_ids[i:i+100]
        ids_param = ','.join(chunk)
        
        try:
            response = requests.get(f'{url}?ids={ids_param}', headers=headers)
            response.raise_for_status()
            features_data = response.json()['audio_features']
            
            for feature in features_data:
                if feature is not None:
                    all_audio_features.append(feature)
            
            print(f"Processed chunk {i//100 + 1}/{(len(valid_track_ids)-1)//100 + 1}")
            time.sleep(0.2)
            
        except requests.exceptions.HTTPError as e:
            print(f"Warning: Failed to get audio features for chunk: {e}")
            continue
    
    return all_audio_features

# --- GET ARTIST INFO ---
def get_artists_info(access_token: str, artist_ids: List[str]) -> List[dict]:
    """Fetches artist information including genres."""
    url = 'https://api.spotify.com/v1/artists'
    headers = {'Authorization': f'Bearer {access_token}'}
    all_artists_info = []
    
    unique_artist_ids = list(set([aid for aid in artist_ids if aid]))
    
    for i in range(0, len(unique_artist_ids), 50):
        chunk = unique_artist_ids[i:i+50]
        ids_param = ','.join(chunk)
        
        try:
            response = requests.get(f'{url}?ids={ids_param}', headers=headers)
            response.raise_for_status()
            artists_data = response.json()['artists']
            all_artists_info.extend(artists_data)
            
            time.sleep(0.1)
            
        except requests.exceptions.HTTPError as e:
            print(f"Warning: Failed to get artist info for chunk: {e}")
            continue
    
    return all_artists_info

# --- MAIN EXECUTION ---
def main():
    print("1. Getting access token...")
    try:
        token = get_spotify_token()
        print("Successfully obtained access token")
    except Exception as e:
        print(f"Failed to get access token: {e}")
        return

    print("2. Testing playlist access...")
    if not test_playlist_access(token, PLAYLIST_ID):
        return

    print("3. Fetching playlist tracks...")
    tracks_list = get_playlist_tracks(token, PLAYLIST_ID)
    
    if not tracks_list:
        print("No tracks were fetched")
        return
        
    tracks_df = pd.DataFrame(tracks_list)
    print(f"Successfully fetched {len(tracks_df)} tracks")
    
    print("4. Fetching audio features...")
    track_ids = tracks_df['track_id'].tolist()
    audio_features = get_audio_features(token, track_ids)
    
    if not audio_features:
        print("No audio features were fetched")
        final_df = tracks_df
    else:
        audio_features_df = pd.DataFrame(audio_features)
        audio_features_df.rename(columns={'id': 'track_id'}, inplace=True)
        
        final_df = tracks_df.merge(audio_features_df, on='track_id', how='left')
        print(f"Successfully merged {len(audio_features)} audio feature records")
    
    print("5. Fetching artist info...")
    artist_ids = final_df['artist_id'].dropna().tolist()
    if artist_ids:
        artists_info = get_artists_info(token, artist_ids)
        if artists_info:
            artists_df = pd.DataFrame(artists_info)
            artists_genres_df = artists_df[['id', 'genres']].rename(
                columns={'id': 'artist_id', 'genres': 'artist_genres'}
            )
            final_df = final_df.merge(artists_genres_df, on='artist_id', how='left')
            print(f"Added genre info for {len(artists_info)} artists")
    
    print("6. Final data preview:")
    print(final_df.head(3))
    print(f"Dataset shape: {final_df.shape}")
    print(f"Columns available: {list(final_df.columns)}")
    
    final_df.to_csv('spotify_playlist_data.csv', index=False)
    print("7. Data saved to 'spotify_playlist_data.csv'")
    
    if 'danceability' in final_df.columns:
        print("8. Audio Features Summary:")
        audio_cols = ['danceability', 'energy', 'valence', 'tempo', 'acousticness']
        for col in audio_cols:
            if col in final_df.columns:
                print(f"{col}: {final_df[col].mean():.3f} (avg)")

if __name__ == "__main__":
    main()

print(repr('if __name__ == "__main__":'))
# Out:
# 1. Getting access token...
# Successfully obtained access token
# 2. Testing playlist access...
# Successfully accessed playlist!
# Playlist Name: Dreampop & Shoegaze
# Description:
# Number of Tracks: 575
# 3. Fetching playlist tracks...
# Successfully fetched 575 tracks
# 4. Fetching audio features...
# Fetching audio features for 575 valid track IDs...
# Warning: Failed to get audio features for chunk: 403 Client Error: Forbidden for url: https://api.spotify.com/v1/audio-features?ids=24bzJwjGBWtGCs7xKIKQsB,5jtbhF7zGZR4YRMxhLV4V8,01nIMkXQLxBmDKDtQCimM6,01TyFEZu6mHbffsVfxgrFn,7MPSPxCd6aiGZwN0ro0ZSH,4w4me43HNpoIpzrEKM1XGP,4oNXgGnumnu5oIXXyP8StH,26SrlxK6EhVa7EWJ6w5uhE,0kCF7dfqwrw1YEf6LK0B1p,5WHrbMnpBRJCHsQUrGYmxu,4cJOLN346rtOty3UPACsao,43rib0UYJnyrxiIkhamjlY,6IUwiHsyKAZtfBy37Wu4ij,5WNDXcsnWSzWvQl7oPIEeT,7H0ya83CMmgFcOhw0UB6ow,476QHG5G8xxNI9VHTBFfjp,51tJQf4oxTMvONqstKnqmR,6xJSVfI6xi51iJrbm9KjXb,34LohAliZ2QKydqVJcFpwV,1cyRoWGazsa8Vr5qlDfvPP,0AruNp6u8BWaYJL60JrKdQ,7nEZZ1mWK7h98x8ENbQuqJ,4fcitkwj32DFTkqMUGONUu,3bdc7OoVK971mkwLno0cAz,1sbipnxbVjDy3kxrAavIoX,0qaEJgRNOChRTa6sS1NhJ7,1GHjBjnMJQ420waXq6Ut6I,1Bh0UzthW8pKEnYg7v40Oa,4YLTFu7iyC3q34dvf5hRDq,4TzJGnsfwbBCkJGeunCpVK,3EWRWKU5n62hhp8vgPwgfZ,0SYKAyKuJ44it3586U8XWS,4jXk0iIhcLulPYZ5HU2K8P,0BTaF7WdhyGDuYoQJtv6vb,3AJsTNjbYSH4odSmP1I6ox,7I2XytQ23omSfUfG7JSjYT,7M9LKoGmelhGBj5jQACPd8,4DN8w5wT01BCgJQdjvMaGi,4gm0sPmthOSICA82Dtol6D,0tx9tLDxgsFPbkwXV0mDUy,5Omjn5QunxCALPISaMJ5K6,0ANkVKMExMdJxl1g88fWJT,2q4gGYNmNYNyqgpVmGJH0c,0HPCLfG38YNyay8Erznli1,1Rw3gR78vpdrymyM3AhZ5x,6lUJAypVpKhMznxO2sAPqd,7Lpi2otSpwKiTpFsdDKEzP,5lLz6hpqvOxKJ5JEoU8otF,43oYosEmgldBQfuVgDQ5F4,3Y38zzhKEvoZeWONUewG1f,2Ti4s01vnOpkOsApYcE3Ia,6jygYHo8uOttsIs45U1YvI,7dCz4BVR2DvfLBo0tabZHC,6RDVwKLpBBEksWdp9jwBlD,2CL9DIH08V6ZrpsmDMcZxM,0oXwUeFAE6IR2lYhaTpxRT,1t3nMYYdEvbubaD5FMDglq,716OZGLBg3vkNfMTpfbYm6,1fKWgfG23FbMhgJXmpOp9A,0jn3fksZqM7Y48xrQZNCsA,7vKMp9RBcZHn9ZaZhy2DVv,2bkOjWXPUdSxIUbd1c2WE9,370jeVUskG6BD6QJljNxBi,65O6zPSisPj2AvAjaY4Bfg,5H5oEqpRA3ARPohkT3yotf,7KsSVeIuhW0QYnrHQw5DOl,38GUrVBl6kXy46GZ24eRso,6cQfMDknRIubCllrhWTdPF,3Opk9C8pMgBCmbqXelH0I5,46Q055p0kvvoeIcM9iXzVP,5ZGxxHixxBV7j9o1uUZFKc,6GdbwI8ytDROXDv1G7p34o,2i1jIsRpjjzaV85v1fS4Hu,1fFiMu3FP6c3kkEpZ0nvvp,74tjwmN794NeMpgF7957No,1BqdhRbDE6mGbYiugML9MK,66QzJkyag2NRX8d8R5HTpU,1CfstJ04dLfJZ9Qq2rPhNo,1BXmmQIGaH3QtGAsG7yV2s,0IV4l6XVCM9iIt2tOTkw84,0JaQLijrOWfRPwJQUrp8ov,3e1Rff6j4s9IMNEPsKpaEz,0Fc8hmAuH0rHYq2Ur9t07Y,2IDyBrueJ5SKlYPA0CZan6,5BRjl7ilBLgpJxhrRle1FT,0cWEqBpSYDRK9Aw3mNb95F,4KHrUUWS3AxhQBooKDzfnD,2F63erfPWawQ2l29agdLFa,4wnUKmSNaXlURtm5m7nkJ9,2Nt4Uw91pQLXSJ28SttDdF,17Gp4Qf260mjouuq6CPcza,4PQSDHGXXxNojUC7BO6lWw,0o1N4jfVOXErcR82UKxfO8,1qrV076T6ZPUPQ2iMgI51s,3vZ57jnq0IgiKXkuWea37P,2BCFf69uK4HL8eOubSSrHm,3jZ0GKAZiDMya0dZPrw8zq,3FOQLkdWvosfpgKsNfIB5J,35yZkNFNVosiHE6Uj0COVM,08qrX56kp9zdeDWidJPCZk
# Warning: Failed to get audio features for chunk: 403 Client Error: Forbidden for url: https://api.spotify.com/v1/audio-features?ids=3EA4HwrlLdDJ3b4cX7JfqC,1fIM60oElZPBuNTV0fqBl0,6N2kBsYvZaS7tO5awPcnSV,51bnedhUHDZViazmNJtzqF,2gNDXjyjAE3VFGmukcixYf,1oUVuepLlKVvqMpvCU62eV,0RDGEI7iXY4Zon0JzJF53B,3YufkKqsssZ8wt9T24ULSj,1jylZOai0G9TI6Font5Nd2,0E8ztdwAhGJ6KRdElKGQT4,2BJvyF65XyGPdhaZT4H9sE,6GbUsMfAF9dFe3vLAO5am9,7DZ0naWyh4SvPeoG8R4FaO,3O7b7tz4PxF5pFTknkXpNc,25MelCAD6ISeCRIh8oKj6N,4dV9LNfCGzEoHixlUsxo5n,1eWPK7TFW0bpEqcbUeCEr3,4aMUQAbISJ4KdR3mqZgLu9,0EuxDK2ria7tszAZdtaJWZ,4gbablSu3oqwlrdgwrBPkY,0SDF7K2lUUNgertEQH4qk7,11umm7K1uVhXYvKK3Tpsa8,2WUKigdj6FjOwty6hQM2ii,0IDku5ISIqZvrsTpCzkAI8,5g1Izt4F2GxmVDZFPJSS4d,3omjo9CqdcjJZmcg1JzCA6,74FaSRytSs5BLu0HnW8fDh,4GN3kfwzPnPZx6rcVaU9UR,5d8pKJxoDlYX2SoFR6RCsm,5pP3sLkAVZ03hyJ6SbsprC,0OcP0ZD8f5paG9taHQNspu,6tpahX6DwbhjAfRoI2xom1,3VM6MAN7KCagEN0hqKB5qm,3c1f3Kl9jbfPUv82Uy2CUM,5xzi36lGj5f6SpbctCpwhB,73guNXAOFu7XB6Sby4ahCp,0Sqqo1gN4bAUDyjNmvM4F4,3dOv8QQIA2soR55wElpb4b,7qWw2fvNABDo75M33uzZL2,61gbBOCTUKyMc0GgEy0DME,1SdDW5OpzeprPbfjC3xFth,46o6ZqJY0nXj0LGJXhwDhD,0fEBMAHBmkX4cdPWXuXzRe,266j4fCyIUXECBch8zE8YZ,3ETUDzHZP3Ue3C767F9jxM,7ly8RGycjJddqh0RsBwMpt,76MJsF1rbbhrv2tDBfeRR5,5pQXoXlUoNIv7L0PvY9E26,77IywFOJxAk4uwdIss1Qsr,6bzK06aFN4kmKaANKsm1iX,0EBfZ9zn0TyJN7kHy3IaoG,0onaz2Qk1UN5qYYhVBCCi3,7Hk79n5xPJHaD2WEcjTTDp,3mBrAr5OurGGsWCIhBj50W,0rumXNTbR7QyBJJDPrSHT7,4Yc8jFRkmAr9qV4mzB95BG,58MZCECkYGPvrcU4IGjqPA,16NVlEnoPlHNJ4EpEZPROC,4vD4GNg2RwuuKkH8CWoxXB,2l1UgRD35MieMii4LyYksT,3yR8cAdli5Ohn3dUlS1PgV,0zi7IKFDOqsaV073v4f4Qc,4pNaaHNfuI3hSDthqatgbi,4a5XE0MLRfMo7JmZFTxvR3,1GUQMJtIIMBLoEJNyDGA0X,5MNthJmhGd0USHhwSDwsif,53FCh1Yv1gdlnybyYWsyca,3qVVCH9Bzzzw1PrmaIfA01,2259JjmM2CzFpm2zVZjva8,0ZAdCDeysyoh5BOpuSGKy3,7EyOP1aNxYNNO9MgEmJCAI,6HxVluu2FEK5JiPVs39gau,2xmgRoRx5GrZpm06GfI3XL,2VTpAdcsIbZ3qhRJaA9bVX,3jeR3DJ0eJErtVvnzRLD6r,1gvaxqNiJEbQzWPqs72kgG,6oeABvJGU7Oztzd3CiSv0l,0xdCRmVLdaxNxF0oAQInsi,0DRvClQbN9znQ295sx76VC,6ziC3mMtZcB77liomN0u7i,79FbfiFCk34V4W1XCDGuqO,15fSe0A90WtPu1wHqCCWcB,3krLB8UbnVrO5eoNX4nFG6,7eqFExt8qLJZ5wyaVEWIFJ,3twm1m2HtONUDBkUE4iPju,3HKLkBOOsSRAHPrOPs7Hxp,0CXzFobArjJTc0P23KftZy,4yJjv9ii2kk02tIWZLzRei,7x4tFmih1JBITx0e2ucGrT,1Jl74ao9nBADj4KtQmwCIF,2K0HAp3di1AvmIjYYdPk4J,3tPh7vkXySn2lUEH1NEPyO,6BY4ZlhDAnswI7ww8jZxrP,4qQFwn7DUSL3qV8psue32d,50wiHcvfcpQSo5P5rbyozc,4UADR6fNQfx4fxkiRQvSy2,0TEakF2OKW4GhTYnYpDCLF,5Gcwao0M9mKVdDH2X1pqnv,6Xwn68W3xQsfyydaTbm6sC,0wA37T62tYBAWl5lKIcOxm
# Warning: Failed to get audio features for chunk: 403 Client Error: Forbidden for url: https://api.spotify.com/v1/audio-features?ids=2jXdenospFSqnRdkszCKJe,3nmpt6D8VQ85pkOl6eMhQo,3x8Ra8xCOkKJx71yoQeMyR,2N4B9Gkkqthx9zH07REjT5,7kzKXQm4eeTJOaFeelCQs0,2op4rJ4v3FptY3BzYLA25l,3cE923w64jGhkQZtprJ2lY,1YJHbR3ANXFNu7NY4vgcDe,1SIfVtJcLhkJfCYDBup6Ya,042KPCog3XmnFjvnZThKTZ,3Lwx7IULdFzJFIPKFGFH9z,35skgcj6FERxuJLQxGBXcn,4FkzwqbQ9ScrcnzIgRPkXT,4soIPMs2XqUFu9roKupZ8I,2d4VlnTyBVserhtyH3b9BZ,4n3xrJ5ptORsVPZLl4qNcV,4pnipOyqSfpDzeKpBPdOG0,0NyE3z63bQpiqDkx6DSjl0,6wMJAqpKp7CsU6YCIPscPC,7d9212orrSfVHQaSdesffl,0MwAi8hSPCDpZM8TU6jHuR,6Hqmu4TRXQjYEq6u1AgnJe,2KZXbaru3Q8J4QOB1hYnTF,7gUWHJbkQ5sCekRghQWIAy,04DdNbTmZAgHfNP6FdY3Sa,2JpsSsuWKEcmqQEKRHEGMu,7McZS9J6h0SKoZBR6cfcFe,1LzNfuep1bnAUR9skqdHCK,3kxKzo6rE1TtPeS3PzsM2w,7wE4l1GNxjE2kOmlsx0PcA,1SDKfHhfBUBciO2AUwuvgI,6PGrkeJpDpgiFLvgKYD489,6zJ8TiWgwoxxlQnZgCH7hS,17djDdG4A6RaonAObaffsH,3MPFzBWdqwaAeCSQpA7Ift,73FmWCru7YZIfFSuGSuEKu,1KPDAA9zyJXcEDvFW5inYi,1DCmcz9n9uGHLJofhITGwi,3arsql2gOlBUnTaFpIjHqE,4GwT2PoXxURFAsbX1DOzjd,7tXyHzeEfr3LLSSdm6rTY8,6ijXqCGHU0YI5prMb4keGO,3F395GaOXCVNDozy5WpK4j,4EDj8GXOlI45vG4SOfswK3,2nr9WZdKntw9a5muEC3gOk,7tQBd6ZxIvhNRcWNtQ8qUT,58jGSwikO2NbCICODjZnrG,0UQc1EkgxdIB3nGVTuAXKI,1z0DXbixgwEiXUZUCKVYsP,4jEGjl1Wj3iSYwDo36cfYX,7svpAkwc6xaSxlbZ7V7JiS,3bATRbSvB9RLyFmSAyBmVD,6113aOfHIC0vbZVDZ6PpRV,7MZCwFGKIoCI00xmCrnRCX,4SPi5Pl7aAtauFsH9Lk5LB,5OuRT9nu8P5GHkoF7MiOiZ,7DwTXozAa7reiJ7KVcSM4N,3n8AnbWYvnpRSoRHGmpBv3,4MzxTLiP3trlFUpL1PAu5S,0MpsyFvt1KaxNYBYw2aanq,43OyGApGeirDOLmSD9aiy2,7EzKrIF3T2XqUZfhnHw5CE,5UVBumEwdUnzvqxrXOYLFA,4S50BYwWW4fnmzQmMqATM4,0v8UvAhruTvkA90MR7039n,2enPRFda84VE2wtI8c86Uf,1I3f8tsoYbIPEgQ1TPvJPb,4I9Z0ey3dKuNRlap1AKHnn,6zqfL2Io4GGtVTz1Agrow1,7KCB9JMl1tSSGGPeNtGdpO,0ZdSPHnoFUAE1tck8oxSyJ,2MhhQE3JTYMge7eCVl2dNT,7l5XWtUfIclO2xCTFvts8V,6smJCC2En1iEuN3b9ZQnLX,5Xxa91usdK0epjlUyRtHeH,498rJ13u7pBsT7datcqL8Q,5XX6Odv28En2TnabZmOn5E,3BdHMOIA9B0bN53jbE5nWe,1xlXSAmoYsirVEevjnfGMw,6WirzZViqdjM0nEtHMA3el,33ySDZzyzAPwscr6zl93FE,7hhIjiXL3BnAikwbLlijpC,5dLVPZd9DTpd17UlKrOWa1,4PoTRZnQhOMJM9VMIS2pVh,772AbCLRS8bocvm3hOODVE,1rUI6I8IKZEtYBL0S8rfXa,3ozeIgf9g4assFBsLDjDP9,3xk9UqibrbMjahj2mtmSdx,3w91918dPywkczARMO5tnJ,3xvVuLA3YYZPd5mx8NOnN6,4rbKtilX985FyoAnHrzCdH,6Lbou6DLY96jA6i9DC2vXA,5etys3p3H0qRDscHy7eWKc,33HRECrmuelZxOpid6XTNX,29p70QrSO4d843jPTSeOZn,6LreV0dZjQlOQQ6foYChc5,1DZtAtt3VKQoDTemC9EKXa,5Ek17fBK5XaIQK9Em7a423,1TFjgmDNqtfw2R0ruYZkUI,3E3dnHbmTxANxgMqKrf1go
# Warning: Failed to get audio features for chunk: 403 Client Error: Forbidden for url: https://api.spotify.com/v1/audio-features?ids=00AHMSjW85Qs1ByBoHzEID,0AgghN0YfYSZRilCXOb3do,3NwaVr6RJg2LPBcJ1Ysl1O,6jt9wki3cLPpJuPK5ntkOH,2I8Dwm2GctXWW4MMPp5Vap,0GN3fXUdsTHeUg50xfDS0V,0B8zyV6NOayK5dEwGiu2lt,4AdjaWMV4ZkY1WeiwH6xwe,7n53Rr7s0NrE56vUNnR4wl,4wJsfg40fFsNUbspoRbgDP,2hWnuDzcKznJvlCxuRgfaA,4iaAD4qbSBs2cfXHTzcYFW,7gePpUawLnGf1l1fnltiIR,19XHp8wmXHLegxZRiA0Kmy,4J9LOhzDYiASTnXdOgG6I1,0wQ0pqFkVoi3NoAcmyx9G5,5ql5pS6ERwE5U5PYPMHbdu,1wXJjKJy5Pt38Bu3tUzTUL,2Ru2ARMNAATgPDL0aSDFCU,6NQfUZb5VummNR8rozb8Ic,5Df8KiHPJSjexHqxDF6Txr,0K8N0F3efUhd55TxNGgmGD,3Ao4ZsCSZvXZ4M4r9yzUUZ,7zTkKCqiFMqXfBKcmlMDgQ,6TSTKAxF5ZawWLzgiBHzkf,0rEVhkcwdi9CcKANWYV0Ot,0qQGx2TyjtZNDNyRYO9Z0W,3GOO81yxm6EZLkiXLs2sx2,1rcxltU3Mzn8gN6Z8ly9Zh,0dCfgEyxU3RyOBtAZw3vPm,4T7okh1A7MmqS7xXypO0wx,3stWWPN41byqp8loPdy92u,2kz4JUPAQLcaViOVgYxzfF,47Y4i7hLPazl7BS4sGWsYd,6G7rDUqMhnmXFVwRRQ7azu,3FiDA9GX921AiW7iEpYS3K,5Jl1QnoXsEsRJOOoXHApab,2ztHL4aV76oeCe6DDWpky3,2XnHYXyjgeuN8dB5VEGquF,6PZUWoycpXj6SKgU2OtmPy,3AHSYM6974K1tw61oMGG8Y,6lmuSzEMhDWWkHZSQ0SXyR,6Ijmj8Z0L31hCp5pLZnT5U,0U3u0HdRQjD8mAMYBak4Ok,0e1XGhjLynaRO0P3KxkxDs,2ngVZZGrIYAxyxaA2QcWTB,54H7CLmI5SE7wmhlE0THS5,2JL5aOSgBVijhW28Bxfczm,46YxybUOOH2MYRXBoHXUgw,7vQp9oEEojNtALtfejGND7,6uFXA44CcLLWbNY5kYSOK6,1gyIYA98zceKTnjISviYRz,44YINUlW44gTcQJKrmGeuK,4qgNoDm7QIpbtt3qB96RzY,0NVEtqedqqSAe2fxFuI6vf,5j375wUE1V53HpkKtiDKT2,3cKzdHoTN1g39ktjm3twCF,3KjGgXIX3RIkBrb4j9vU7C,1W91GlNLLC6y0xXg1RLtie,24UzJSXpXqmGXrGjqAOFpY,3BAZa1WlbTZoWPoKcJRtE2,7Bo3nnosClsnmd67p6tacd,3BMcTB54pN4oZlIIPNxcy1,5lJDgnn9Wq06dBoEdMyXuz,1Vb0Wc8s6cFOKrUj8ZNHnV,4QgIkSyVxv6FmsWO2dZz4J,79PaJyGdIi8XN6d9tp2YlT,67RdRmkIRxl3iShk1hknwo,3agVTNFmPXfrqQXnxoMyeM,1X6YvgGzWH9t6io3ZBZ7JP,4GjWZDfWw5ZnW9vmioJwY0,1EokSSh35Ym77YxH7CkTqz,204Yva4BgTADZrtq7h4MNH,0HAsOUxDiYHKaQSoKKEN5z,1C9t8whBQcIDcI3mwmmFhp,5X632JMfT1LF7P1RtVHV9Q,7EUcNIHj2eWmpGNJF5u0Vh,6fLHeUV8b0qho8xPGiyc6g,5NwyQFaZbL6w8SaFcPFDn8,5ECxlbd1DVZ7CsGCRM6WG0,3XUjzEdbLM6gyXJp5JkHD8,2hc6fCrA3pmmh4EJtzMBs9,298kKazpJHYf8LZaYTwD8n,00ozHYZoGTa3oaOzvOt7oo,595AilWVTfMJLQ9Zi30cmP,1AArLFgUZ2FKMlCWsceAuv,4omurqpm7aWH9VVz2Ii4yO,5HwMuhePwIUpXUv2EI0EiB,6W0LWlasbqwMGxn87NLgKh,6zsaWF1rdzIRCmWJtcteCs,69T4iEoAPo1MZ2tv8ppUCW,0pbpe3m3jK5LKdx3Z5f8KE,7sTmKNOcJrx8wAnbXuLim1,72xnRXxHiAhTfKSzlPdEmo,5fGv33bhHGfMkuDxct0CYh,6Cbw78matPaaagbsSF1wDN,6ZUNNe8T0XAcpyVOMijwQl,1LuuEtc0bgoZYm82p79Dzw,3mALM7a4cLufetyxSUPbl5,6Pw5gYfLcgU3vm4RoeCyUc
# Warning: Failed to get audio features for chunk: 403 Client Error: Forbidden for url: https://api.spotify.com/v1/audio-features?ids=3OHxoCPpoLDca8Jz0Qb4uV,5O408HCYe3tXhyLf5JMjhJ,6Nr8U7LKb4B07ZTbXA1RbX,3zdTA309WHMFZo1l6IAiPu,11HCS8E6veZP3Mkf3f5Kal,3zLorBeTEnHM5UBd8HuCEd,0ptW09x2Qjv00t076WBLWF,6fdRXMZ4oLpnphUMVZCMfi,6V1Ha54suZAAoH9vuKznS6,1iLKFqMqLpfItPRnRUNacj,4eHMLCWUBoQxHuI4XM1hv7,1VqYfdsorchSvhXW6gtBzo,3yXnxzAYIyKYCcydaznZu9,6A0O01z01HXYZhlrAfvxID,3YKt8wJ7kmDfUY23jhtiwv,6aoaCEsh9MLMndlL9G28WM,7wFCijfJQowBt1sNqhWgZS,6FfelarA8SE4RpveYxXuRo,3b6DLf2PTYkrGuPGRhWSXP,3ccsR4VyFNdeQqJTxXRSJA,4XbikCzGo0Zrm6rg9r9jzk,3hVlV66Z3PfvXwIYOTeZdi,7pP1PiLuYDMvWVCbTuasRg,6OrFhhGmqAYsPWryD6b4Ta,7zI7COP0QX8SrmEVlRCzJz,6RSDI2ms9CHIvOnrYzxluR,0wDR2zmN1TCYrXONqNcsWj,60fpp48C0mbRkRNv8m3WLv,5x7Xbw7khyGRjFSlEUenUm,26uHXNWafzDn8SkYB7fZ2r,69moAh6nFUQzBi5lfBJcV0,3Q1DprZauQyNo8KGlY8brZ,3kqG4FUlzH2sE1zFn9L7OR,0vMr3GXZJi1IIIWE8bBJuZ,0LqzKh0IljbOTwKEG15q97,2AENUpRtIxQ5tnk10SaxKL,575Ey6z5iNmWI52iNtyVZh,1Afd5dLyIGTJU69CdNlaGG,30ZUJcx1YtPXuvfcCB0Y3e,1MkAO4seLIDrU20w0RkisU,63jvmVQ8gIQ8NdMX5HEKEE,3HrU7VEECBx1ewUgxRu5xu,13gKSPSKURLYuy92ubSbFq,5PM5PTTrxAXyUmY9JU9qmN,4Xi7V0b226jbmms7I9uZZr,7Icyf6awUQ4WnuUPL86xeG,2KqKu9seZepmo9uKo6VyD8,41KOeMJyeNMzXXMFURLqMv,2lxKEd14HqvyH5oj1E3xxV,2hMNfrmuOjAghUiUnPbFxT,5jh147eWeuNyimT2Oo1A5J,1dtLFRRmiGg2nBaV4Rg9Ux,07iFZgCmzSuGFlKG3ftJX3,5OMp32hhcSCvKITpudjjlv,5Fmk7akgjEpRI4vvu7CQ2m,1bs7Igp2djzz9aWDbEkfYA,0dcu28YT8cXZH7JTIraszp,63JP68VirmCXtWRoMTX8Xi,6P8FKtzzxYE2cNy2kRgzFV,0nj8byYnmEojNsm3nbAIax,57IGLLjpk4CVexlspqOawg,3o2JcCmfnw5d45pWy8BYHu,6LQcFrduZod8SaXNg8BK8z,62DeK5SgEqY3OjcZLPjnh8,6zRQXP7UbHHXwEbe1NaN1k,7ImWMtUZwcnCDGwJKy6br4,5X5qE3xo5UR8auMyJgPVzR,1obYgmAEYuJve71L7r43oP,223R25sVUNY4QCvA7XjkNk,7L3HY8vkvQ47LuzOYbkZGN,2PaIdVLUvoetIBE4J4vPbY,7uHPeQJmdhQMW32Jlyfsmr,1fSS7Mc15YNRuBOsTjyEaw,1ztljnhex2kExHZlSQIvs8,0dQV4vdauTQMbBLgC86EM2,7de72dRB2KvNzwVXYBqFHF,5lIfFxH4PJeqjwDLfORZ0z,0exjXziLpfBAs3QppeYUzo,2czsyBO2UuK9KNWDeNGZC8,2JPZFolVoxO4XU3SJH89tZ,3LG0fOHDELxUJadCiGpyCF,3Gh8L6ULIiFV7AmNlcDHRx,55J97YT1SRzkNGpwm45qSu,7IEw63s69ccxaEZzUsX3Xj,59OB1FVylpLOfwUwwZBBqf,01aponripySMrxA2XTXjkV,5rFLueCMLuVI4Jxp7coerG,0qZngsBTYM37fevbe03IlX,53USlfdBOnCsORa3fJ6Rxb,5udm5l5aFlUDg9i5vU4A0B,0WgwG41CeaJt21sCUHiSIy,6isgkCGX8e47Z9vl6WHebB,60PUlg3G6mSuA8pB5Bjgdw,3zFqzq75hxehVM6DkCSORU,2nznScQCuL4r9OKMr4A7qc,5A6E9uhiiRyJ8OSYQ0IRdt,7zycM9Qcin9tyU4xB0Jj3I,5c0fozcpxmj8jV2BhfvUY8,7hrQx8C3rT5R447bmNnq5Y,0BWUUT2MvwUOQidoOxtwfF
# Warning: Failed to get audio features for chunk: 403 Client Error: Forbidden for url: https://api.spotify.com/v1/audio-features?ids=1u8xwmcIdld5n99GcQDuOs,3CpUfVYoeman5Ceki0AVkI,4vGDSgcS7YHnRtZlM8pWph,4skeJN6yWo5wSRgPjRNFUp,2gF3wvkKkkuAXGFzAPUBSa,0mTGWYKRsvKBRk6DsDHfTT,0yc4bo6GUkb6BhzfKqEd3w,5Qi8sL3cPDEh2LrdjqK3ph,19i0n5BUaXpRzhUUqWYMM7,6vacYnJcKuHCbzok7QYhaY,5Fm6AO50RzXV2tQPb9I0v0,6Io2THanzgOrIAoYS2LZbo,6Y9bhgrbne2ITypFY4bBiE,20xDbepYlgdH63vlVVUb0e,0xSn8K45u9yOIDZysjwz20,055a4S701SWymem8rtYLVy,1NWezW3YWytFOwSOQ5ZWoI,3vuG06ETVyqQlxW2wbBVjg,4uKfukUKqgEnEt5asFocv9,5iCNhiucTLYkVLvDEdlCgb,1ADmIBKMDRcs6Cfj2Xe0XJ,2Zw3HNjaNV42LnQ2uY5JQs,78Cp2OMPai18kVYkd22bAF,1GnhDPcve5uOz4K8StzHtX,49YNqlIbBD2c41o3Oc0vK4,1LomCMl5wD3MPVlC6smUHe,3rQaxZaozQfrUEQx1PzT14,30bPsTvD3ikvd5IvRudsPI,4iOhHhNggDeRP575hUHedH,579zXcYm2N9vvsltW2RDJP,1ENjSTAGfgBUyVZuSl4zIY,2fjE9A6haImVXETd1B4PDs,60c53oKZjSyWUNCrQJ49Bt,1Pr2b8WV0rFkSAjrnzUeDc,596IkZP89HvFYdgOb3lNvP,6X49AzMOL4WQHlNg2nAWSe,2uQotduUA32t7EwTEMvMyb,4IL1YB0CKiX4e9gbodOJBZ,4JV9iLdrBbBkwo0qMfYJ5S,7KIyjTDMad8HvLj5IKBffs,4bFyukeX4nCR9BEY1iuhps,7ne2hzW4jaU5tacaCI4kJH,0ldHaEnSxsSpC1pYa1Vtl6,2DZisSfv1rQ3O5CBLws3sK,0PliQPq7GT7vuShXU61x03,1G6ZnfgxEBhSWd6WO2EB4s,65UDqRVBShlxTOwQtKkfUm,7hLYnfqZ8IlIMxjdTkRFxO,73B21p60Izq74AFwGNhzR7,0eBWL3s1UmZNSZBcy34l6J,00rcoBUdF2W90roBxkS5cG,3bhaEugV9wBPXhxX0p2uYX,4yYw0lE2CJOwwymaob3hX1,1X8E5Ad67vg9bNVRAuNHtX,4FqAv5twjda2qgyp3hqunT,5WZNVZvxQI7Wg3ME4hznV4,4FAOQdOpMAu3d15KEWXMng,3iHDfrkDiR8XBdagsZKsXD,4ELG7XkebKpAFX80Czdwmd,6b9B6v1U2eXO5gLvQOC0pu,20bn8UrHSGODum7utPZhgB,3YxMOcoa7ogJlG4e6zyJwm,1zFDTVldgGkboCG98c91d6,0aXLRXrribyzRhOjEonPeD,50MJMElz3rtuIT3wtunt1G,6uv3mwUvxsS2q8T7yhQuDs,6n1bMD1OYkhfN9B5sQYjg8,7C2bncZ2xUWmAIsfeukLhG,1pqrOSuEubjirB4OyBNHPm,2MpWd718bmGUu7xXjrRtsb,5stsvdWcj7wHpSNalY75w0,0Rft1X2yTA2LXEMGNBIjr5,5Tt63qlnIHU7B3L1XwxXdQ,7cpQwNcUnqqzIRCluyD4ry,1CRP7KciFH1reIOS12JFiA
# No audio features were fetched
# 5. Fetching artist info...
# Added genre info for 287 artists
# 6. Final data preview:
#                track_name                track_id       artist_name  \
# 0              Wildflower  24bzJwjGBWtGCs7xKIKQsB       Beach House
# 1  Perfectly Out Of Place  5jtbhF7zGZR4YRMxhLV4V8  Dreams We've Had
# 2        After the Moment  01nIMkXQLxBmDKDtQCimM6      Craft Spells
#
#                 artist_id          album_name  popularity  duration_ms  \
# 0  56ZTgzPBDge0OvCGgMO3OY   Depression Cherry          66       219453
# 1  5LkgVE79AHNZN7kMukfJFv  Everything And You          41       293454
# 2  16lg8y62dC3J6ok1pNAbFJ    After the Moment           0       243658
#
#    explicit           artist_genres
# 0     False             [dream pop]
# 1     False             [dream pop]
# 2     False  [dream pop, chillwave]
# Dataset shape: (575, 9)
# Columns available: ['track_name', 'track_id', 'artist_name', 'artist_id', 'album_name', 'popularity', 'duration_ms', 'explicit', 'artist_genres']
# 7. Data saved to 'spotify_playlist_data.csv'
# 'if __name__ == "__main__":'

# %%
print(repr('if __name__ == "__main__":'))
# Out:
# 'if __name__ == "__main__":'
